# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from math import sqrt
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.decomposition import PCA
from sklearn import metrics

# %matplotlib inline

# %%
df = pd.read_csv('covid.csv')

# %%
df.columns
# Out:
# Index(['id', 'sex', 'patient_type', 'entry_date', 'date_symptoms', 'date_died',
#        'intubed', 'pneumonia', 'age', 'pregnancy', 'diabetes', 'copd',
#        'asthma', 'inmsupr', 'hypertension', 'other_disease', 'cardiovascular',
#        'obesity', 'renal_chronic', 'tobacco', 'contact_other_covid',
#        'covid_res', 'icu'],
#       dtype='object')

# %%
plt.figure(figsize=(14, 10))
sns.heatmap(df.drop('date_died', axis=1).corr(), cmap='YlGnBu', annot=True, fmt='.2f', vmin=0);

# %% [markdown]
# ### Transformando as datas de morte missing em valores falsos, e datas de morte verdadeiras para true

# %% [markdown]
# As datas nulas ou missing são representadas como '9999-99-99', todos os campos que tiverem esse valor, teremos que transformar em False, ou seja, a pessoa não veio a obito, caso exista uma data real transformamos o valor do campo em True, que no caso a pessoa veio a obito

# %%
def toBool(value):
    if value in'9999-99-99':
        return 0
    else:
        return 1

# %%
dates = df['date_died'].values
new_dates = np.array(list(map(toBool, dates)))
new_dates
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
df['died'] = new_dates

# %% [markdown]
# ### Retiramos as colunas que não são interessantes como atributo de treinamento.

# %%
df = df.drop(columns=['id', 'entry_date', 'date_symptoms', 'date_died'], axis=1)

# %%
df.head()
# Out:
#    sex  patient_type  intubed  pneumonia  age  pregnancy  diabetes  copd  \
# 0    2             1       97          2   27         97         2     2
# 1    2             1       97          2   24         97         2     2
# 2    1             2        2          2   54          2         2     2
# 3    2             2        2          1   30         97         2     2
# 4    1             2        2          2   60          2         1     2
#
#    asthma  inmsupr  hypertension  other_disease  cardiovascular  obesity  \
# 0       2        2             2              2               2        2
# 1       2        2             2              2               2        2
# 2       2        2             2              2               2        1
# 3       2        2             2              2               2        2
# 4       2        2             1              2               1        2
#
#    renal_chronic  tobacco  contact_other_covid  covid_res  icu  died
# 0              2        2                    2          1   97     0
# 1              2        2                   99          1   97     0
# 2              2        2                   99          1    2     0
# 3              2        2                   99          1    2     0
# 4              2        2                   99          1    2     1

# %% [markdown]
# ### Separando atributos de treinamento da variável target

# %%
atributos = df.columns.drop('died')

# %%
target = ['died']

# %%
X = df[atributos].values
Y = df[target].values

# %% [markdown]
# ### Análise de componentes principais (PCA)

# %%
pca = PCA(n_components = 3)

# %%
pca.fit(X)
# Out:
# PCA(n_components=3)

# %%
pca.explained_variance_
# Out:
# array([3382.98806784, 2235.05462711, 1754.57252688])

# %%
pca.explained_variance_ratio_
# Out:
# array([0.42656718, 0.28182214, 0.22123727])

# %%
pca.components_
# Out:
# array([[ 2.10867867e-03,  6.66705363e-03, -6.34050506e-01,
#         -3.80836505e-03,  9.73705541e-02,  1.99695182e-01,
#          6.85155642e-04,  1.76711868e-03,  2.07523144e-03,
#          2.12293694e-03,  4.87957712e-04,  3.30836160e-03,
#          2.07562274e-03,  1.96572820e-03,  1.77908252e-03,
#          2.07244724e-03,  3.82736581e-01, -1.66734870e-03,
#         -6.34056838e-01],
#        [-9.97546334e-03,  6.62571964e-04, -6.30001471e-02,
#         -1.55957886e-04,  1.05367551e-02, -9.53843219e-01,
#         -1.94012034e-03, -1.66059272e-03, -1.70733815e-03,
#         -1.52970312e-03, -2.04704662e-03, -1.99136853e-03,
#         -1.49391628e-03, -1.67748398e-03, -1.56652480e-03,
#         -1.09756408e-03,  2.86364007e-01,  1.63899157e-04,
#         -6.30086529e-02],
#        [-2.34497847e-03,  3.12576408e-03, -2.97546911e-01,
#         -2.03606645e-03,  3.64498591e-02, -2.23939920e-01,
#         -8.40755622e-04, -9.49460233e-04, -7.76058416e-04,
#         -7.43574577e-04, -9.80207440e-04,  1.34236947e-03,
#         -8.27447337e-04, -1.04024297e-03, -9.10388412e-04,
#         -6.65387449e-04, -8.78310984e-01,  3.52924234e-05,
#         -2.97539895e-01]])

# %%
X = pca.transform(X)

# %%
new_df = pd.DataFrame(X, columns=['pc1', 'pc2', 'pc3'])

# %%
new_df['target'] = Y

# %%
sns.pairplot(new_df, vars = ['pc1', 'pc2', 'pc3'], hue='target', diag_kind = 'hist')
plt.show()

# %% [markdown]
# ### Separando dados de treino e dados de teste

# %%
X_treino, X_teste, Y_treino, Y_teste = train_test_split(X, Y, test_size = 0.25, random_state = 2)

# %%
print("{0:0.2f}% nos dados de treino".format((len(X_treino)/len(df.index)) * 100))
print("{0:0.2f}% nos dados de teste".format((len(X_teste)/len(df.index)) * 100))
# Out:
# 75.00% nos dados de treino
# 25.00% nos dados de teste

# %% [markdown]
# ### Tratando valores missing ocultos

# %%
new_df.isnull().values.any()
# Out:
# False

# %% [markdown]
# Na documentação do dataset, valores missing estão representados como 97, 98, 99, menos na coluna idade.

# %%
preenche_0 = SimpleImputer(missing_values = 97, strategy = "most_frequent")
preenche_1 = SimpleImputer(missing_values = 98, strategy = "most_frequent")
preenche_2 = SimpleImputer(missing_values = 99, strategy = "most_frequent")

# %% [markdown]
# Substituindo os valores iguais a 97, 98, 99 pelo valor mais frequente dos dados

# %%
X_treino = preenche_0.fit_transform(X_treino)
X_teste = preenche_0.fit_transform(X_teste)

X_treino = preenche_1.fit_transform(X_treino)
X_teste = preenche_1.fit_transform(X_teste)

X_treino = preenche_2.fit_transform(X_treino)
X_teste = preenche_2.fit_transform(X_teste)

# %% [markdown]
# ### Criando Modelo usando o algoritmo de classificação de Naive Bayes

# %%
modelo_v1 = GaussianNB()

# %%
modelo_v1.fit(X_treino, Y_treino.ravel())
# Out:
# GaussianNB()

# %% [markdown]
# ### Verificando acurácia do modelo

# %%
nb_predict_test = modelo_v1.predict(X_teste)

# %%
print('X_teste ', X_teste.shape)
print('X_treino ', X_treino.shape)
print('Y_teste ', Y_teste.shape)
print('Y_treino ', Y_treino.shape)
# Out:
# X_teste  (141651, 3)
# X_treino  (424951, 3)
# Y_teste  (141651, 1)
# Y_treino  (424951, 1)

# %%
Y_treino.shape
# Out:
# (424951, 1)

# %%
print("Acurácia: {0:.4f}".format(metrics.accuracy_score(Y_teste, nb_predict_test)))
# Out:
# Acurácia: 0.9085

# %% [markdown]
# ### Matriz de confusão

# %%
metrics.confusion_matrix(Y_teste, nb_predict_test, labels = [1, 0])
# Out:
# array([[  4694,   4535],
#        [  8432, 123990]], dtype=int64)

# %% [markdown]
# ### Curva ROC

# %%
fpr, tpr, thresholds = metrics.roc_curve(Y_teste, nb_predict_test)
metrics.auc(fpr, tpr)
# Out:
# 0.7224694654580157

# %%
modelo_v1.score(X_teste, Y_teste)
# Out:
# 0.9084581118382503
